# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from google.colab import files
files.upload()   # upload the zip of your dataset in yolov8 format

# %%
# !unzip landingpad.v5i.yolov8.zip -d /content/datasets/landingpad

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.2/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
model = YOLO("yolov8n.pt")

model.train(
    data="/content/datasets/landingpad/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.239 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r detect.zip runs/detect
files.download("detect.zip")
